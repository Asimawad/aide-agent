# %%
# required for the full workflow (file operations, data handling, model definition, image processing, etc.).
import os
import random
import numpy as np
import pandas as pd
from sklearn.model_selection import (
    train_test_split,
)  # For splitting datasets later in the plan
import torch
import torch.nn as nn
from PIL import Image
import cv2
import timm
import albumentations as A
import transformers


# Thought: Define a set_seed function to enforce reproducibility across random, numpy, and torch operations.
def set_seed(seed_value: int):
    random.seed(seed_value)
    np.random.seed(seed_value)
    torch.manual_seed(seed_value)
    if torch.cuda.is_available():
        torch.cuda.manual_seed_all(seed_value)
    # Enforce deterministic behavior at the cost of performance
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False


# Thought: Set the seed to ensure that experiments are reproducible as we develop our pipeline.
set_seed(42)

# Thought: Define the primary PyTorch device to leverage GPU if available, ensuring optimal computation.
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
